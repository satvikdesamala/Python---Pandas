# %%
import pandas as pd
pd.set_option('display.max.row', 20)

# %%
df = pd.read_csv(r"C:\Users\kallzz\Desktop\Data Analytics Stuff\Data Analyst - Boot Camp\Python - Jupyter Notebooks\Datasets\world_population.csv")

# %%
df
# Out:
#      Rank CCA3            Country           Capital Continent  \
# 0      36  AFG        Afghanistan             Kabul      Asia
# 1     138  ALB            Albania            Tirana    Europe
# 2      34  DZA            Algeria           Algiers    Africa
# 3     213  ASM     American Samoa         Pago Pago   Oceania
# 4     203  AND            Andorra  Andorra la Vella    Europe
# ..    ...  ...                ...               ...       ...
# 229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    46  YEM              Yemen             Sanaa      Asia
# 232    63  ZMB             Zambia            Lusaka    Africa
# 233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# 0         41128771.0       38972230.0       33753499.0       28189672.0
# 1          2842321.0        2866849.0        2882481.0        2913399.0
# ...

# %%
# set index - method 1
df = pd.read_csv(r"C:\Users\kallzz\Desktop\Data Analytics Stuff\Data Analyst - Boot Camp\Python - Jupyter Notebooks\Datasets\world_population.csv", index_col = 'Country')
df
# Out:
#                    Rank CCA3           Capital Continent  2022 Population  \
# Country
# Afghanistan          36  AFG             Kabul      Asia       41128771.0
# Albania             138  ALB            Tirana    Europe        2842321.0
# Algeria              34  DZA           Algiers    Africa       44903225.0
# American Samoa      213  ASM         Pago Pago   Oceania          44273.0
# Andorra             203  AND  Andorra la Vella    Europe          79824.0
# ...                 ...  ...               ...       ...              ...
# Wallis and Futuna   226  WLF          Mata-Utu   Oceania          11572.0
# Western Sahara      172  ESH          El Aaiún    Africa         575986.0
# Yemen                46  YEM             Sanaa      Asia       33696614.0
# Zambia               63  ZMB            Lusaka    Africa       20017675.0
# Zimbabwe             74  ZWE            Harare    Africa       16320537.0
#
# ...

# %%
# reset index
df.reset_index(inplace = True)
df
# Out:
#      index  Rank CCA3            Country           Capital Continent  \
# 0        0    36  AFG        Afghanistan             Kabul      Asia
# 1        1   138  ALB            Albania            Tirana    Europe
# 2        2    34  DZA            Algeria           Algiers    Africa
# 3        3   213  ASM     American Samoa         Pago Pago   Oceania
# 4        4   203  AND            Andorra  Andorra la Vella    Europe
# ..     ...   ...  ...                ...               ...       ...
# 229    229   226  WLF  Wallis and Futuna          Mata-Utu   Oceania
# 230    230   172  ESH     Western Sahara          El Aaiún    Africa
# 231    231    46  YEM              Yemen             Sanaa      Asia
# 232    232    63  ZMB             Zambia            Lusaka    Africa
# 233    233    74  ZWE           Zimbabwe            Harare    Africa
#
#      2022 Population  2020 Population  2015 Population  2010 Population  \
# ...

# %%
df.set_index('Country')
# Out:
#                    index  Rank CCA3           Capital Continent  \
# Country
# Afghanistan            0    36  AFG             Kabul      Asia
# Albania                1   138  ALB            Tirana    Europe
# Algeria                2    34  DZA           Algiers    Africa
# American Samoa         3   213  ASM         Pago Pago   Oceania
# Andorra                4   203  AND  Andorra la Vella    Europe
# ...                  ...   ...  ...               ...       ...
# Wallis and Futuna    229   226  WLF          Mata-Utu   Oceania
# Western Sahara       230   172  ESH          El Aaiún    Africa
# Yemen                231    46  YEM             Sanaa      Asia
# Zambia               232    63  ZMB            Lusaka    Africa
# Zimbabwe             233    74  ZWE            Harare    Africa
#
#                    2022 Population  2020 Population  2015 Population  \
# Country
# Afghanistan             41128771.0       38972230.0       33753499.0
# ...

# %%
# multi index
df.set_index(['Continent','Country'], inplace=True)

# %%
df.sort_index()
# Out:
#                             index  Rank CCA3      Capital  2022 Population  \
# Continent     Country
# Africa        Algeria           2    34  DZA      Algiers       44903225.0
#               Angola            5    42  AGO       Luanda       35588987.0
#               Benin            21    77  BEN   Porto-Novo       13352864.0
#               Botswana         26   144  BWA     Gaborone        2630296.0
#               Burkina Faso     31    58  BFA  Ouagadougou       22673762.0
# ...                           ...   ...  ...          ...              ...
# South America Paraguay        161   109  PRY     Asunción        6780744.0
#               Peru            162    44  PER         Lima       34049588.0
#               Suriname        199   170  SUR   Paramaribo         618040.0
#               Uruguay         223   133  URY   Montevideo        3422794.0
#               Venezuela       227    51  VEN      Caracas       28301696.0
#
# ...

# %%
df.sort_index(ascending = [True, False]) # sorts Capital in asc and country in dsc
# Out:
#                               index  Rank CCA3       Capital  2022 Population  \
# Continent     Country
# Africa        Zimbabwe          233    74  ZWE        Harare       16320537.0
#               Zambia            232    63  ZMB        Lusaka       20017675.0
#               Western Sahara    230   172  ESH      El Aaiún         575986.0
#               Uganda            217    31  UGA       Kampala       47249585.0
#               Tunisia           212    79  TUN         Tunis       12356117.0
# ...                             ...   ...  ...           ...              ...
# South America Colombia           42    28  COL        Bogota       51874024.0
#               Chile              40    65  CHL      Santiago       19603733.0
#               Brazil             27     7  BRA      Brasilia      215313498.0
#               Bolivia            24    80  BOL         Sucre       12224110.0
#               Argentina           8    33  ARG  Buenos Aires       45510318.0
#
# ...

# %%
df.loc['Africa']
# Out:
#                 index  Rank CCA3      Capital  2022 Population  \
# Country
# Algeria             2    34  DZA      Algiers       44903225.0
# Angola              5    42  AGO       Luanda       35588987.0
# Benin              21    77  BEN   Porto-Novo       13352864.0
# Botswana           26   144  BWA     Gaborone        2630296.0
# Burkina Faso       31    58  BFA  Ouagadougou       22673762.0
# ...               ...   ...  ...          ...              ...
# Tunisia           212    79  TUN        Tunis       12356117.0
# Uganda            217    31  UGA      Kampala       47249585.0
# Western Sahara    230   172  ESH     El Aaiún         575986.0
# Zambia            232    63  ZMB       Lusaka       20017675.0
# Zimbabwe          233    74  ZWE       Harare       16320537.0
#
#                 2020 Population  2015 Population  2010 Population  \
# Country
# Algeria              43451666.0       39543154.0       35856344.0
# ...

# %%
df.loc['Africa', 'Algeria']
# Out:
# index                                   2
# Rank                                   34
# CCA3                                  DZA
# Capital                           Algiers
# 2022 Population                44903225.0
# 2020 Population                43451666.0
# 2015 Population                39543154.0
# 2010 Population                35856344.0
# 2000 Population                30774621.0
# 1990 Population                25518074.0
# 1980 Population                18739378.0
# 1970 Population                13795915.0
# Area (km²)                      2381741.0
# Density (per km²)                 18.8531
# Growth Rate                        1.0164
# World Population Percentage          0.56
# Name: (Africa, Algeria), dtype: object

# %%
df.iloc[1]
# Out:
# index                                  1
# Rank                                 138
# CCA3                                 ALB
# Capital                           Tirana
# 2022 Population                2842321.0
# 2020 Population                2866849.0
# 2015 Population                2882481.0
# 2010 Population                2913399.0
# 2000 Population                3182021.0
# 1990 Population                3295066.0
# 1980 Population                2941651.0
# 1970 Population                2324731.0
# Area (km²)                       28748.0
# Density (per km²)                98.8702
# Growth Rate                       0.9957
# World Population Percentage         0.04
# Name: (Europe, Albania), dtype: object

# %%
df.iloc[1,1] # it doesn't work with multi indexes
# Out:
# 138
